# %% [markdown]
# <a href="https://colab.research.google.com/github/Suvrakar/Data_visualization_python/blob/master/linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

X=(.6, .2, 1.2, .8)
Y=(.2, .66, 1.5, .99)

plt.plot(X,Y)
plt.title("Test")
plt.ylabel("T 1")
plt.xlabel("T 2")
# Out:
# Text(0.5, 0, 'T 2')
